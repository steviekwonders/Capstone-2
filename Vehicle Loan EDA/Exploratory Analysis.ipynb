# %%
# We will start this portion off by viewing histograms and barplots for continuous and categorial features, respectively.
import pandas as pd
import numpy as np
import os
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats

# %%
# Save path and get current working directory. 
path = "/Users/student/Desktop/SpringBoardDSCareerTrack/Capstone 2 Datasets/Vehicle Loan Payments/data"
os.chdir(path)
os.getcwd()
# Out:
# '/Users/student/Desktop/SpringBoardDSCareerTrack/Capstone 2 Datasets/Vehicle Loan Payments/data'

# %%
# Check the first few records. 
df = pd.read_csv('Vehicle_Loan_DataWrang.csv')
df.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    537409             47145       65550  73.23         67        22807
# 2    417566             53278       61360  89.63         67        22807
# 3    624493             57513       66113  88.48         67        22807
# 4    539055             52378       60300  88.39         67        22807
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441    1984-01-01        Salaried  ...
# 1               45                1502    1985-07-31   Self employed  ...
# 2               45                1497    1985-08-24   Self employed  ...
# 3               45                1501    1993-12-30   Self employed  ...
# 4               45                1495    1977-12-09   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
# Look at statistics for continuous variables (numerical features). 
df.describe()
# Out:
#             UniqueID  disbursed_amount    asset_cost            ltv  \
# count  233154.000000     233154.000000  2.331540e+05  233154.000000
# mean   535917.573376      54356.993528  7.586507e+04      74.746530
# std     68315.693711      12971.314171  1.894478e+04      11.456636
# min    417428.000000      13320.000000  3.700000e+04      10.030000
# 25%    476786.250000      47145.000000  6.571700e+04      68.880000
# 50%    535978.500000      53803.000000  7.094600e+04      76.800000
# 75%    595039.750000      60413.000000  7.920175e+04      83.670000
# max    671084.000000     990572.000000  1.628992e+06      95.000000
#
#            branch_id    supplier_id  manufacturer_id  Current_pincode_ID  \
# count  233154.000000  233154.000000    233154.000000       233154.000000
# mean       72.936094   19638.635035        69.028054         3396.880247
# std        69.834995    3491.949566        22.141304         2238.147502
# ...

# %%
# Save the feature names into a list: features
feature = list(df.columns)

# %%
# Save features of type 'int'. 'categ_features' 
categ_features = []
# Save features of type 'float' into num_features.
num_features = []

# Assume, for now, that if feature is of type int, it's categorical and add to categorial list.
for val in feature:
    if df[val].dtypes == 'int64' or df[val].dtypes == 'object':
        categ_features.append(val)
    else:
        num_features.append(val)

print('Categorical features: ', categ_features); print('\n')
print('Numerical features: ', num_features)
# Out:
# Categorical features:  ['UniqueID', 'disbursed_amount', 'asset_cost', 'branch_id', 'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth', 'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID', 'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag', 'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE', 'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT', 'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES', 'loan_default']
#
#
# Numerical features:  ['ltv']

# %%
# Assuming features of type int to be categorical was a bad idea. Remove features in categorial list that should be 
# numerical (should be plotted via histogram) and add it to numerical features list.
to_be_numerical = ['disbursed_amount', 'asset_cost', 'PERFORM_CNS.SCORE', 'PRI.NO.OF.ACCTS', 
                   'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT',
                   'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT', 
                   'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT', 'NEW.ACCTS.IN.LAST.SIX.MONTHS', 
                   'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 'NO.OF_INQUIRIES']

for feat in to_be_numerical:
    categ_features.remove(feat)
    num_features.append(feat)
    
print('Categorical features ', categ_features, '(length): ',  len(categ_features)); print('\n')
print('Numerical features  ', num_features, '(length): ', len(num_features)); print('\n')
print('Shared feature(s) between categorical and numerical lists:', list(set(categ_features) & set(num_features)))
# Out:
# Categorical features  ['UniqueID', 'branch_id', 'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth', 'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID', 'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag', 'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE.DESCRIPTION', 'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'loan_default'] (length):  20
#
#
# Numerical features   ['ltv', 'disbursed_amount', 'asset_cost', 'PERFORM_CNS.SCORE', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS', 'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT', 'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS', 'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT', 'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT', 'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 'NO.OF_INQUIRIES'] (length):  21
#
#
# Shared feature(s) between categorical and numerical lists: []

# %%
defaulter = df[df['loan_default']==1]
nondefaulter = df[df['loan_default']==0]

# %%
# Function for plotting a histogram.
def plothistogram(var_name, bins):
    plt.subplots(1,2,figsize=(12,4))
    plt.subplot(1,2,1)
    ax = df[var_name].hist(bins = bins, color = 'b')
    ax.set_ylabel('Count') 
    ax.set(xlim=(df[var_name].quantile(0.01), df[var_name].quantile(0.99)))   
    ax.set_xlabel(var_name)
    ax.set_title('Overall Frequency distribution for ' + var_name)
    print('Summary statistics for', var_name)
    return df[var_name].describe()

# %%
def createviolinplot(var_name):
    # This code block will create a violin plot for continuous variables. It will make two violin plots for defaulters 
    # and non-defaulters ('loan_default' value of 1 and 0 respectively). It will also return the t-test statistic in
    # difference of means to verify if the two samples have the same average.
    plt.subplot(1,2,2)
    sns.violinplot(x = 'loan_default', y=var_name, data= df)
    defaulter = df[df['loan_default']==1][var_name]
    nondefaulter = df[df['loan_default']==0][var_name]
    print('Nondefaulter mean for', var_name, ':' ,nondefaulter.mean(), ', std:', nondefaulter.std()) 
    print('Defaulter mean for ', var_name, ': ', defaulter.mean(), ', std:', defaulter.std())
    return scipy.stats.ttest_ind(defaulter, nondefaulter, equal_var = False)

# %%
# Function to plot barplot. Additionally, return the chi-square test stat between default (obs_freq) and non-default (exp_freq)
def plotbarplot(var_name):
    # This code block will create a barplot for categorical variable.
    df.groupby([var_name])[[var_name]].count().plot(kind='bar', color='b').set_ylabel('Count')
    defaulter = df[df['loan_default']==1]
    nondefaulter = df[df['loan_default']==0]
    
    # This code block will create two dictionaries for defaulters and nondefaulters for specified variable. It will obtain
    # percentage for each categorical value which we can use in chi-square test to see if there is difference in their distribution.
    var_name_values = list(df[var_name].unique())
    exp_freq = {}; obs_freq = {}
    
    for val in var_name_values:
        if val not in list(defaulter[var_name].unique()):
            obs_freq[val] = 0
        else:
            obs_freq[val] = defaulter[defaulter[var_name] == val][var_name].count()/len(defaulter)
            
    for val in var_name_values:
        if val not in list(nondefaulter[var_name].unique()):
            exp_freq[val] = 0
        else:
            exp_freq[val] = nondefaulter[nondefaulter[var_name] == val][var_name].count()/len(nondefaulter)
    
    return scipy.stats.chisquare(list(obs_freq.values()), list(exp_freq.values()) )             # do chi-square on dictionary values

# %%
def plotbardefaulter(var_name):
    # This code block will create a bar plot of specified categorical variable for defaulters. This will be used
    # if chi-square shows significance and we want to see how the distribution differs from the overall barplot. 
    defaulter = df[df['loan_default']==1]
    defaulter.groupby([var_name])[[var_name]].count().plot(kind='bar', color='r').set_ylabel('Default Count')

# %%
# Histogram for disbursed amount of loan
print(plothistogram('disbursed_amount', int(np.sqrt(len(df)))) ); print('\n')
createviolinplot('disbursed_amount')
# Out:
# Summary statistics for disbursed_amount
# count    233154.000000
# mean      54356.993528
# std       12971.314171
# min       13320.000000
# 25%       47145.000000
# 50%       53803.000000
# 75%       60413.000000
# max      990572.000000
# Name: disbursed_amount, dtype: float64
#
#
# Nondefaulter mean for disbursed_amount : 53826.47111091633 , std: 13140.699007454747
# Defaulter mean for  disbursed_amount :  56270.47386931695 , std: 12150.255527172361
# Ttest_indResult(statistic=39.32291321262725, pvalue=0.0)

# %%
# Histogram for asset_cost
print(plothistogram('asset_cost', int(np.sqrt(len(df))))); print('\n')
createviolinplot('asset_cost')
# Out:
# Summary statistics for asset_cost
# count    2.331540e+05
# mean     7.586507e+04
# std      1.894478e+04
# min      3.700000e+04
# 25%      6.571700e+04
# 50%      7.094600e+04
# 75%      7.920175e+04
# max      1.628992e+06
# Name: asset_cost, dtype: float64
#
#
# Nondefaulter mean for asset_cost : 75722.80612787124 , std: 19015.002867400784
# Defaulter mean for  asset_cost :  76378.17666120014 , std: 18680.50260861944
# Ttest_indResult(statistic=6.9564139258295805, pvalue=3.516464322816128e-12)

# %%
# Histogram for loan to value
print(plothistogram('ltv', 50)); print('\n')
createviolinplot('ltv')
# Out:
# Summary statistics for ltv
# count    233154.000000
# mean         74.746530
# std          11.456636
# min          10.030000
# 25%          68.880000
# 50%          76.800000
# 75%          83.670000
# max          95.000000
# Name: ltv, dtype: float64
#
#
# Nondefaulter mean for ltv : 74.15409333691578 , std: 11.681454560472389
# Defaulter mean for  ltv :  76.88332180751246 , std: 10.327771446422924
# Ttest_indResult(statistic=51.07804645618371, pvalue=0.0)

# %%
# Histogram for Performance CNS Score
print( plothistogram('PERFORM_CNS.SCORE', 40) ); print('\n')
createviolinplot('PERFORM_CNS.SCORE')
# Out:
# Summary statistics for PERFORM_CNS.SCORE
# count    233154.000000
# mean        289.462994
# std         338.374779
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%         678.000000
# max         890.000000
# Name: PERFORM_CNS.SCORE, dtype: float64
#
#
# Nondefaulter mean for PERFORM_CNS.SCORE : 299.7842700076146 , std: 342.88379369485415
# Defaulter mean for  PERFORM_CNS.SCORE :  252.23637153978385 , std: 318.8262417091854
# Ttest_indResult(statistic=-29.194543952774662, pvalue=1.8706268585937013e-186)

# %%
# Histogram for Total # of loans taken at time of loan disbursement
print( plothistogram('PRI.NO.OF.ACCTS', int(np.sqrt(len(df)))) ); print('\n')
createviolinplot('PRI.NO.OF.ACCTS')
# Out:
# Summary statistics for PRI.NO.OF.ACCTS
# count    233154.000000
# mean          2.440636
# std           5.217233
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           3.000000
# max         453.000000
# Name: PRI.NO.OF.ACCTS, dtype: float64
#
#
# Nondefaulter mean for PRI.NO.OF.ACCTS : 2.538037613055554 , std: 5.261141650230395
# Defaulter mean for  PRI.NO.OF.ACCTS :  2.089328406868072 , std: 5.040133626442075
# Ttest_indResult(statistic=-17.551839983016315, pvalue=7.654548297713226e-69)

# %%
# Histogram for Total # of active loans at time of loan disbursement
print( plothistogram('PRI.ACTIVE.ACCTS', int(np.sqrt(len(df)))) ); print('\n')
createviolinplot('PRI.ACTIVE.ACCTS')
# Out:
# Summary statistics for PRI.ACTIVE.ACCTS
# count    233154.000000
# mean          1.039896
# std           1.941496
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           1.000000
# max         144.000000
# Name: PRI.ACTIVE.ACCTS, dtype: float64
#
#
# Nondefaulter mean for PRI.ACTIVE.ACCTS : 1.0822710265526478 , std: 2.00824201211921
# Defaulter mean for  PRI.ACTIVE.ACCTS :  0.8870601252692103 , std: 1.669965727209364
# Ttest_indResult(statistic=-22.218089920490065, pvalue=4.359373016274794e-109)

# %%
# Histogram for Total # of existing default accounts at time of loan disbursement
print(plothistogram('PRI.OVERDUE.ACCTS',250)); print('\n')
createviolinplot('PRI.OVERDUE.ACCTS')
# Out:
# Summary statistics for PRI.OVERDUE.ACCTS
# count    233154.000000
# mean          0.156549
# std           0.548787
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          25.000000
# Name: PRI.OVERDUE.ACCTS, dtype: float64
#
#
# Nondefaulter mean for PRI.OVERDUE.ACCTS : 0.14473849996987012 , std: 0.5320262425891056
# Defaulter mean for  PRI.OVERDUE.ACCTS :  0.19914643061784987 , std: 0.6034839757822149
# Ttest_indResult(statistic=18.396887850172355, pvalue=2.0528996536265e-75)

# %%
# Histogram for Total principal loan amounts at time of loan disbursement
print( plothistogram('PRI.CURRENT.BALANCE', int(np.sqrt(len(df)))) ); print('\n')
createviolinplot('PRI.CURRENT.BALANCE')
# Out:
# Summary statistics for PRI.CURRENT.BALANCE
# count    2.331540e+05
# mean     1.659001e+05
# std      9.422736e+05
# min     -6.678296e+06
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      3.500650e+04
# max      9.652492e+07
# Name: PRI.CURRENT.BALANCE, dtype: float64
#
#
# Nondefaulter mean for PRI.CURRENT.BALANCE : 179487.57931008036 , std: 994631.7352945375
# Defaulter mean for  PRI.CURRENT.BALANCE :  116892.87601509553 , std: 720451.2837836256
# Ttest_indResult(statistic=-15.809980160208736, pvalue=3.064521576878215e-56)

# %%
# Histogram for Total amount sanctioned at time of loan disbursement
print( plothistogram('PRI.SANCTIONED.AMOUNT', 2500) ); print('\n')
createviolinplot('PRI.SANCTIONED.AMOUNT')
# Out:
# Summary statistics for PRI.SANCTIONED.AMOUNT
# count    2.331540e+05
# mean     2.185039e+05
# std      2.374794e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      6.250000e+04
# max      1.000000e+09
# Name: PRI.SANCTIONED.AMOUNT, dtype: float64
#
#
# Nondefaulter mean for PRI.SANCTIONED.AMOUNT : 232639.50497690955 , std: 1234346.7457193038
# Defaulter mean for  PRI.SANCTIONED.AMOUNT :  167519.6049672996 , std: 4525738.059420641
# Ttest_indResult(statistic=-3.2041575164865144, pvalue=0.0013553891514135757)

# %%
# Histogram for Total amount disbursed at time of loan disbursement
print( plothistogram('PRI.DISBURSED.AMOUNT', 2500) ); print('\n')
createviolinplot('PRI.DISBURSED.AMOUNT')
# Out:
# Summary statistics for PRI.DISBURSED.AMOUNT
# count    2.331540e+05
# mean     2.180659e+05
# std      2.377744e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      6.080000e+04
# max      1.000000e+09
# Name: PRI.DISBURSED.AMOUNT, dtype: float64
#
#
# Nondefaulter mean for PRI.DISBURSED.AMOUNT : 232032.56919191644 , std: 1240214.8264108973
# Defaulter mean for  PRI.DISBURSED.AMOUNT :  167691.1196577819 , std: 4527095.229860132
# Ttest_indResult(statistic=-3.1646202069948868, pvalue=0.0015537370611620543)

# %%
# Histogram for Secondary Total loans taken by customer at time of loan disbursement
print( plothistogram('SEC.NO.OF.ACCTS', int(np.sqrt(len(df)))) ); print('\n')
createviolinplot('SEC.NO.OF.ACCTS')
# Out:
# Summary statistics for SEC.NO.OF.ACCTS
# count    233154.000000
# mean          0.059081
# std           0.626795
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          52.000000
# Name: SEC.NO.OF.ACCTS, dtype: float64
#
#
# Nondefaulter mean for SEC.NO.OF.ACCTS : 0.06184844118919926 , std: 0.6516570890284885
# Defaulter mean for  SEC.NO.OF.ACCTS :  0.04909999802414495 , std: 0.5273583476262503
# Ttest_indResult(statistic=-4.558447180586419, pvalue=5.159558673623707e-06)

# %%
# Histogram for Secondary active loans taken by customer at time of loan disbursement
print( plothistogram('SEC.ACTIVE.ACCTS',int(np.sqrt(len(df))) ) ); print('\n')
createviolinplot('SEC.ACTIVE.ACCTS')
# Out:
# Summary statistics for SEC.ACTIVE.ACCTS
# count    233154.000000
# mean          0.027703
# std           0.316057
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          36.000000
# Name: SEC.ACTIVE.ACCTS, dtype: float64
#
#
# Nondefaulter mean for SEC.ACTIVE.ACCTS : 0.028700087102764827 , std: 0.3233747412831527
# Defaulter mean for  SEC.ACTIVE.ACCTS :  0.02410543162553595 , std: 0.28809588122653623
# Ttest_indResult(statistic=-3.0887418425253683, pvalue=0.002010678047385409)

# %%
# Histogram for secondary principal loan amount of customer at time of loan disbursement
print( plothistogram('SEC.CURRENT.BALANCE', 6000) ); print('\n')
createviolinplot('SEC.CURRENT.BALANCE')
# Out:
# Summary statistics for SEC.CURRENT.BALANCE
# count    2.331540e+05
# mean     5.427793e+03
# std      1.702370e+05
# min     -5.746470e+05
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.603285e+07
# Name: SEC.CURRENT.BALANCE, dtype: float64
#
#
# Nondefaulter mean for SEC.CURRENT.BALANCE : 5923.6213440120955 , std: 184110.75765852304
# Defaulter mean for  SEC.CURRENT.BALANCE :  3639.445891209421 , std: 106044.42506894954
# Ttest_indResult(statistic=-3.5765186710197896, pvalue=0.0003483153747562231)

# %%
# Histogram for secondary sanctioned loan amount of customer at time of loan disbursement
print( plothistogram('SEC.SANCTIONED.AMOUNT', 4000) ); print('\n')
createviolinplot('SEC.SANCTIONED.AMOUNT')
# Out:
# Summary statistics for SEC.SANCTIONED.AMOUNT
# count    2.331540e+05
# mean     7.295923e+03
# std      1.831560e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.000000e+07
# Name: SEC.SANCTIONED.AMOUNT, dtype: float64
#
#
# Nondefaulter mean for SEC.SANCTIONED.AMOUNT : 7908.738253452611 , std: 195212.28973438882
# Defaulter mean for  SEC.SANCTIONED.AMOUNT :  5085.631680859892 , std: 130717.868085271
# Ttest_indResult(statistic=-3.8192712593557556, pvalue=0.00013391389999004152)

# %%
# Histogram for secondary disbursed loan amount of customer at time of loan disbursement
print( plothistogram('SEC.DISBURSED.AMOUNT', 4000) ); print('\n')
createviolinplot('SEC.DISBURSED.AMOUNT')
# Out:
# Summary statistics for SEC.DISBURSED.AMOUNT
# count    2.331540e+05
# mean     7.179998e+03
# std      1.825925e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.000000e+07
# Name: SEC.DISBURSED.AMOUNT, dtype: float64
#
#
# Nondefaulter mean for SEC.DISBURSED.AMOUNT : 7780.733892836209 , std: 194597.53945618658
# Defaulter mean for  SEC.DISBURSED.AMOUNT :  5013.272154274762 , std: 130392.7661245395
# Ttest_indResult(statistic=-3.7542781318277707, pvalue=0.00017392386103331586)

# %%
# Histogram for EMI Amount of Primary Loan
print( plothistogram('PRIMARY.INSTAL.AMT', 1500) ); print('\n')
createviolinplot('PRIMARY.INSTAL.AMT')
# Out:
# Summary statistics for PRIMARY.INSTAL.AMT
# count    2.331540e+05
# mean     1.310548e+04
# std      1.513679e+05
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      1.999000e+03
# max      2.564281e+07
# Name: PRIMARY.INSTAL.AMT, dtype: float64
#
#
# Nondefaulter mean for PRIMARY.INSTAL.AMT : 13951.592813747993 , std: 157963.98513594718
# Defaulter mean for  PRIMARY.INSTAL.AMT :  10053.740846851475 , std: 124665.51133348931
# Ttest_indResult(statistic=-5.851207445431919, pvalue=4.8952880447036405e-09)

# %%
# Histogram for EMI Amount of Secondary Loan
print( plothistogram('SEC.INSTAL.AMT', 3000) ); print('\n')
createviolinplot('SEC.INSTAL.AMT')
# Out:
# /Users/student/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: Attempting to set identical left == right == 0.0 results in singular transformations; automatically expanding.
#   import sys
# Summary statistics for SEC.INSTAL.AMT
# count    2.331540e+05
# mean     3.232684e+02
# std      1.555369e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      4.170901e+06
# Name: SEC.INSTAL.AMT, dtype: float64
#
#
# Nondefaulter mean for SEC.INSTAL.AMT : 335.9501706447248 , std: 16588.052553484686
# Defaulter mean for  SEC.INSTAL.AMT :  277.5282053308569 , std: 11045.628444415664
# Ttest_indResult(statistic=-0.9333428035286238, pvalue=0.3506448699686936)

# %%
# Histogram for new loans taken out in last six months
print(plothistogram('NEW.ACCTS.IN.LAST.SIX.MONTHS', 500))
createviolinplot('NEW.ACCTS.IN.LAST.SIX.MONTHS')
# Out:
# Summary statistics for NEW.ACCTS.IN.LAST.SIX.MONTHS
# count    233154.000000
# mean          0.381833
# std           0.955107
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          35.000000
# Name: NEW.ACCTS.IN.LAST.SIX.MONTHS, dtype: float64
# Nondefaulter mean for NEW.ACCTS.IN.LAST.SIX.MONTHS : 0.3966188788395063 , std: 0.9729689997391793
# Defaulter mean for  NEW.ACCTS.IN.LAST.SIX.MONTHS :  0.3285056608247219 , std: 0.885661148793889
# Ttest_indResult(statistic=-14.976441038053645, pvalue=1.209930473858775e-50)

# %%
# Histogram for delinquent accounts in last six months 
print(plothistogram('DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS', 500))
createviolinplot('DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS')
# Out:
# Summary statistics for DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS
# count    233154.000000
# mean          0.097481
# std           0.384439
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          20.000000
# Name: DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS, dtype: float64
# Nondefaulter mean for DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS : 0.09050470300148458 , std: 0.3702351321845456
# Defaulter mean for  DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS :  0.12264132303254233 , std: 0.43087164170442177
# Ttest_indResult(statistic=15.287394706935459, pvalue=1.1212118691400999e-52)

# %%
# Barplot for number of inqueries 
print(plothistogram('NO.OF_INQUIRIES', 500))
createviolinplot('NO.OF_INQUIRIES')
# Out:
# Summary statistics for NO.OF_INQUIRIES
# count    233154.000000
# mean          0.206615
# std           0.706498
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max          36.000000
# Name: NO.OF_INQUIRIES, dtype: float64
# Nondefaulter mean for NO.OF_INQUIRIES : 0.19036610552034317 , std: 0.6655358308412611
# Defaulter mean for  NO.OF_INQUIRIES :  0.26521902353243365 , std: 0.8351467924441973
# Ttest_indResult(statistic=18.593062163375365, pvalue=5.630274017008783e-77)

# %%
# Barplot for branch id. PROBABLY leave OUT of model
print(plotbarplot('branch_id'))
print('Top 5 most numerous branches of non-defaulters', nondefaulter.groupby('branch_id')['branch_id'].count().sort_values(ascending=False).head())
print('\n')
print('Top 5 most numerous branches of defaulters', defaulter.groupby('branch_id')['branch_id'].count().sort_values(ascending=False).head())
# rank which branches had highest default rates
# Out:
# Power_divergenceResult(statistic=0.07722253732153758, pvalue=1.0)
# Top 5 most numerous branches of non-defaulters branch_id
# 2     10683
# 67     9130
# 3      7616
# 5      7171
# 34     6375
# Name: branch_id, dtype: int64
#
#
# Top 5 most numerous branches of defaulters branch_id
# 36    2621
# 2     2455
# 67    2198
# 5     2047
# 16    1815
# Name: branch_id, dtype: int64

# %%
# Barplot for supplier id. WILL PROBABLY USE IN MODEL
print(plotbarplot('supplier_id'))
plotbardefaulter('supplier_id')
print('Top 5 most numerous suppliers of non-defaulters', nondefaulter.groupby('supplier_id')['supplier_id'].count().sort_values(ascending=False).head())
print('\n')
print('Top 5 most numerous suppliers of defaulters', defaulter.groupby('supplier_id')['supplier_id'].count().sort_values(ascending=False).head())
# Out:
# /Users/student/opt/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:5745: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs - f_exp)**2 / f_exp
# Power_divergenceResult(statistic=inf, pvalue=0.0)
# Top 5 most numerous suppliers of non-defaulters supplier_id
# 18166    1028
# 14375     988
# 17980     983
# 15663     967
# 18317     950
# Name: supplier_id, dtype: int64
#
#
# Top 5 most numerous suppliers of defaulters supplier_id
# 18317    482
# 15694    386
# 22994    341
# 21980    336
# 14234    320
# Name: supplier_id, dtype: int64

# %%
# Barplot for manufacturer id. PROB won't use
print(plotbarplot('manufacturer_id'))
# Out:
# Power_divergenceResult(statistic=0.01227498642992129, pvalue=0.9999999999999278)

# %%
# Barplot for current pincode ID. PROB USE!
print(plotbarplot('Current_pincode_ID'))
print('Top 5 most numerous pincode ID of non-defaulters', nondefaulter.groupby('Current_pincode_ID')['Current_pincode_ID'].count().sort_values(ascending=False).head())
print('\n')
print('Top 5 most numerous pincode_ID of defaulters', defaulter.groupby('Current_pincode_ID')['Current_pincode_ID'].count().sort_values(ascending=False).head())
# Zoom in
# r those do sort and look at htyhe first few
# when you have many bars
#so show only the one with large numbers
# Out:
# Power_divergenceResult(statistic=inf, pvalue=0.0)
# Top 5 most numerous pincode ID of non-defaulters Current_pincode_ID
# 2578    1478
# 1446    1386
# 1515     894
# 1509     714
# 1794     683
# Name: Current_pincode_ID, dtype: int64
#
#
# Top 5 most numerous pincode_ID of defaulters Current_pincode_ID
# 2578    402
# 1446    345
# 2943    305
# 2989    301
# 2782    223
# Name: Current_pincode_ID, dtype: int64

# %%
# Bar plot for date of birth. PROB WONT USE! 
# df['Date.of.Birth'] = df['Date.of.Birth'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))
df['BirthYear'] = pd.DatetimeIndex(df['Date.of.Birth']).year
print(plotbarplot('BirthYear'))
# Out:
# Power_divergenceResult(statistic=0.0105834340714621, pvalue=1.0)

# %%
# Bar plot for state from which loan was disbursed. PROB WONT USE
print(plotbarplot('State_ID'))
# Out:
# Power_divergenceResult(statistic=0.04404341953698229, pvalue=1.0)

# %%
# Barplot for Employee of organization who disbursed the loan. PROBABLY USE! 
print(plotbarplot('Employee_code_ID'))
plotbardefaulter('Employee_code_ID')
print('Top 5 most numerous Employee_code_ID of non-defaulters', nondefaulter.groupby('Employee_code_ID')['Employee_code_ID'].count().sort_values(ascending=False).head())
print('\n')
print('Top 5 most numerous Employee_code_ID of defaulters', defaulter.groupby('Employee_code_ID')['Employee_code_ID'].count().sort_values(ascending=False).head())
# again look at the sort and look at the ones that hae many samples
# if you have id with few samples the statistics will not work anyway 
# plot big values but still keep every value in data
# you an aggregate all the one that snaller than 20 saple under a single ategory "others"
# Out:
# Power_divergenceResult(statistic=inf, pvalue=0.0)
# Top 5 most numerous Employee_code_ID of non-defaulters Employee_code_ID
# 620     337
# 255     336
# 2153    315
# 130     306
# 751     293
# Name: Employee_code_ID, dtype: int64
#
#
# Top 5 most numerous Employee_code_ID of defaulters Employee_code_ID
# 2546    348
# 620     165
# 255     158
# 184     119
# 1110    113
# Name: Employee_code_ID, dtype: int64

# %%
# Barplot for Credit Risk Score. PROB WONT USE! 
print(plotbarplot('PERFORM_CNS.SCORE.DESCRIPTION'))
# Let's see the credit score brackets for each description.
df.groupby(['PERFORM_CNS.SCORE.DESCRIPTION'])['PERFORM_CNS.SCORE'].max()
# Out:
# Power_divergenceResult(statistic=0.05501450434611593, pvalue=1.0)
# PERFORM_CNS.SCORE.DESCRIPTION
# A-Very Low Risk                                            890
# B-Very Low Risk                                            805
# C-Very Low Risk                                            760
# D-Very Low Risk                                            735
# E-Low Risk                                                 705
# F-Low Risk                                                 680
# G-Low Risk                                                 650
# H-Medium Risk                                              630
# I-Medium Risk                                              600
# J-High Risk                                                570
# K-High Risk                                                520
# L-Very High Risk                                           350
# M-Very High Risk                                           300
# ...

# %%
# Come back to fix y axis limits!! PROB WILL USE! 
print(plotbarplot('AVERAGE.ACCT.AGE'))
# Out:
# Power_divergenceResult(statistic=inf, pvalue=0.0)

# %%
# PROB WILL USE! 
print(plotbarplot('CREDIT.HISTORY.LENGTH'))
# Out:
# Power_divergenceResult(statistic=inf, pvalue=0.0)

# %% [markdown]
# Thusfar, we have identified each feature as either a categorial or numerical and plotted their respective bar plots and histograms. We have also created plots for borrowers who have defaulted in their first EMI payment ('loan_default' value of 1) which is our target variable.

# %% [markdown]
# We will verify whether any of the independent features are too correlated (should be dependent). We can think about removing some of these variables.

# %%
# See the pearson correlations for each pair of features.
df.corr()
# Out:
#                                      UniqueID  disbursed_amount  asset_cost  \
# UniqueID                             1.000000          0.145575    0.144671
# disbursed_amount                     0.145575          1.000000    0.752668
# asset_cost                           0.144671          0.752668    1.000000
# ltv                                 -0.030537          0.376747   -0.301188
# branch_id                           -0.004509          0.018328    0.018586
# supplier_id                          0.025747          0.078596    0.150002
# manufacturer_id                     -0.021514          0.095203   -0.005256
# Current_pincode_ID                   0.030500          0.068540    0.275878
# State_ID                            -0.057734         -0.023956   -0.026348
# Employee_code_ID                     0.075983          0.010120    0.008711
# MobileNo_Avl_Flag                         NaN               NaN         NaN
# ...

# %%
# By looking at this heatmap, we can find independent features that have high correlation. We want to remove 'redundancy'
# when we make the actual model. It looks like some features with high correlation are: 
# 'SEC.NO.OF.ACCTS' and 'SEC.ACTIVE.ACCTS': 0.83 
# 'PRI.NO.OF.ACCTS' and 'PRI.ACTIVE.ACCTS': 0.75, 
# 'asset_cost' and 'ltv': 0.7, 
# 'SEC.SANCTIONED.AMOUNT' and 'SEC.CURRENT.BALANCE': 0.93'
# 'SEC.CURRENT.BALANCE' and 'SEC.DISBURSED.AMOUNT': 0.93', 
# 'NEW.ACCT.IN.LAST.SIX.MONTHS' and 'PRI.ACTIVE.ACCTS':0.7 
plt.subplots(figsize=(35,28))
sns.heatmap(df.corr(), annot=True)

# %%
## Q. target not continuous so can't do scatter plot. what to do...?
# in this case you can use a box plot 
# to show the relation between continues and the target 
# and a bar plot for the categorical and the target 
# you can show the ratiofor each category 

# TO DO LIST. 
# For barplots that are hard to read... only plot ones with large values and group small values into 'other'
